# %% [markdown]
# <a href="https://colab.research.google.com/github/weeckom/V1/blob/main/Python_Notebook_Setup_by_Weecko_Malate_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Research Question # 2 : Is there an association between how often you isolate yourself and how often you have mood swings?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://drive.google.com/file/d/1IbHzUMYKFBkmW3TIvryP7XJlW-WkmGEw/view?usp=sharing'
path= 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df.head()
# Out:
#        AID  BIO_SEX        agew1 IMONTH4 IDAY4 IYEAR4   MACNO4 INTID4  \
# 0  5710027        2
# 1  5710131        2  19.42739726       5     6   2008  2288160    160
# 2  5710317        1
# 3  5710386        1  20.43013699       5    22   2008  2288238    238
# 4  5710455        2
#
#   BIO_SEX4 VERSION4  ... H4EO5C H4EO5D H4EO5E H4EO5F H4EO5G H4EO5H H4EO5I  \
# 0                    ...
# 1        2     V5.4  ...      0      0      0      0      0      0      0
# 2                    ...
# 3        1     V5.4  ...      0      0      0      0      0      0      0
# 4                    ...
#
#   H4EO5J H4EO6 H4EO7
# 0
# 1      0     2     1
# 2
# 3      0     4     1
# 4
#
# [5 rows x 976 columns]

# %%
pip install researchPy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import researchpy as rp

# %% [markdown]
# Codebook 1:
#
# ![v3.png](data:image/png;base64,...)

# %%
#Manage data for variable 1
df['Isolate'] = df['H4MH2']
df['Isolate'].value_counts()
# Out:
# 0    2004
# 1    1636
#      1390
# 2    1201
# 3     272
# 8       1
# Name: Isolate, dtype: int64

# %%
df['Isolate'] = df['Isolate'].loc[ df['Isolate'] !=' ' ]
df['Isolate'] = df['Isolate'].loc[ df['Isolate'] !='8' ]
df['Isolate'].value_counts()
# Out:
# 0    2004
# 1    1636
# 2    1201
# 3     272
# Name: Isolate, dtype: int64

# %%
df['Isolate'].replace(['0', '1', '2', '3'] , ['NEVER', 'FEWTIMES', 'SOMETIMES', 'OFTEN'], inplace = True)
df['Isolate'].value_counts()
# Out:
# NEVER        2004
# FEWTIMES     1636
# SOMETIMES    1201
# OFTEN         272
# Name: Isolate, dtype: int64

# %%
rp.summary_cat(df['Isolate'])
# Out:
#   Variable    Outcome  Count  Percent
# 0  Isolate      NEVER   2004    39.19
# 1            FEWTIMES   1636    32.00
# 2           SOMETIMES   1201    23.49
# 3               OFTEN    272     5.32

# %%
#Graphs and tables or statistics
plt.title("How often do you feel isolated from others?")
explode = (0.1, 0.1, 0.2, 0.2, 0.3)
df['Days_missed'].value_counts().plot(kind ='pie', autopct='%1.1f%%', explode=explode, shadow=True, startangle=10, colors=['lavenderblush', 'lightpink', 'pink','palevioletred'])
# Out:
# <Axes: title={'center': 'How often do you feel isolated from others?'}, ylabel='Days_missed'>

# %%
plt.xlabel("Isolate")
plt.title("How often do you feel isolated from others?")
df['Isolate'].value_counts(normalize = True).plot(kind ='barh', color = 'palevioletred', width = 0.8, alpha = 0.5)
# Out:
# <Axes: title={'center': 'How often do you feel isolated from others?'}>

# %% [markdown]
# Codebook 2:
#
# ![v4.png](data:image/png;base64,...)

# %%
#Manage data for variable 1
df['Mood_swings'] = df['H4PE4']
df['Mood_swings'].value_counts()
# Out:
# 4    2040
#      1391
# 2    1102
# 3    1091
# 5     575
# 1     297
# 6       5
# 8       3
# Name: Mood_swings, dtype: int64

# %%
df['Mood_swings'] = df['Mood_swings'].loc[ df['Mood_swings'] !=' ' ]
df['Mood_swings'] = df['Mood_swings'].loc[ df['Mood_swings'] !='6' ]
df['Mood_swings'] = df['Mood_swings'].loc[ df['Mood_swings'] !='8' ]
df['Mood_swings'].value_counts()
# Out:
# 4    2040
# 2    1102
# 3    1091
# 5     575
# 1     297
# Name: Mood_swings, dtype: int64

# %%
df['Mood_swings'].replace(['1', '2', '3', '4', '5'] , ['STRONGLYAGREE', 'AGREE', 'NEUTRAL', 'DISAGREE', 'STRONGLYDISAGREE'], inplace = True)
df['Mood_swings'].value_counts()
# Out:
# DISAGREE            2040
# AGREE               1102
# NEUTRAL             1091
# STRONGLYDISAGREE     575
# STRONGLYAGREE        297
# Name: Mood_swings, dtype: int64

# %%
#Graphs and tables or statistics
plt.title("I have frequent mood swings")
explode = (0.1, 0.1, 0.2, 0.2, 0.3)
df['Mood_swings'].value_counts().plot(kind ='pie', autopct='%1.1f%%', explode=explode, shadow=True, startangle=10, colors=['thistle', 'plum', 'mediumorchid', 'mediumpurple', 'violet'])
# Out:
# <Axes: title={'center': 'I have frequent mood swings'}, ylabel='Mood_swings'>

# %%
plt.xlabel("Mood_swings")
plt.title("I have frequent mood swings")
df['Mood_swings'].value_counts(normalize = True).plot(kind ='barh', color = 'thistle', width = 0.8, alpha = 0.5)
# Out:
# <Axes: title={'center': 'I have frequent mood swings'}>
